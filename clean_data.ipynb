# %%
import pandas as pd
import regex
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-321eeacab511> in <module>
#       1 import pandas as pd
# ----> 2 import regex
#
# ModuleNotFoundError: No module named 'regex'

# %%
df = pd.read_csv("data1.csv")

# %%
df.shape
# Out:
# (9199, 7)

# %%
df.tail()
# Out:
#                    a_date        a_post_id  \
# 9194  2020-08-01 20:49:15  961149611068430
# 9195  2020-08-01 20:48:52  961149274401797
# 9196  2020-08-01 20:48:39  961149141068477
# 9197  2020-08-01 20:48:33  961149064401818
# 9198  2020-08-01 20:47:26  961148384401886
#
#                                                a_source  \
# 9194  Nguyễn Việt Anh,Mua bán nhà, chung cư, bất độn...
# 9195  Trần Thu Thu,Mua bán nhà, chung cư, bất động s...
# 9196  Ngoc Thanh,Mua bán nhà, chung cư, bất động sản...
# 9197  Thành Đào,Mua bán nhà, chung cư, bất động sản ...
# 9198  Vũ Thắng,Mua bán nhà, chung cư, bất động sản V...
#
#                                                  a_text  \
# 9194  - Chủ nhà chuyển lên chung cư ở cần bán gấp nh...
# 9195  🌎🌎lô Đất 388,7m2 Có 200tc , Mặt tiền 23m ,  🌏🌏...
# 9196                           - Liên hệ: 0908.816.222.
# 9197                              LIÊN HỆ: 0908.816.222
# 9198  Chủ nhà cần bán căn nhà Phố Bạch Mai, Hai Bà T...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9199 entries, 0 to 9198
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   a_date         9199 non-null   object
#  1   a_post_id      9199 non-null   object
#  2   a_source       9058 non-null   object
#  3   a_text         8929 non-null   object
#  4   b_url          9199 non-null   object
#  5   d_comment_url  9199 non-null   object
#  6   pictures       8593 non-null   object
# dtypes: object(7)
# memory usage: 503.2+ KB

# %%
df[df.a_text.isnull()]
# Out:
#                    a_date        a_post_id  \
# 149   2020-08-09 20:52:49  967302077119850
# 150   2020-08-09 20:18:29  967280517122006
# 221   2020-08-09 18:57:18  967229133793811
# 222   2020-08-09 18:07:23  967186223798102
# 223   2020-08-09 17:15:41  967155040467887
# ...                   ...              ...
# 9035  2020-07-26 20:02:05  956652291518162
# 9036  2020-07-26 20:01:59  956652221518169
# 9114  2020-07-26 17:49:30  956568888193169
# 9149  2020-08-01 21:17:57  961169307733127
# 9191  2020-08-01 20:51:22  961151297734928
#
#                                                a_source a_text  \
# 149   Hoàng Hải Nam,Mua bán nhà, chung cư, bất động ...    NaN
# 150   Nguyễn Khánh,Mua bán nhà, chung cư, bất động s...    NaN
# 221   Hường Trần,Mua bán nhà, chung cư, bất động sản...    NaN
# 222   Nghiem Minh Tu,Mua bán nhà, chung cư, bất động...    NaN
# 223   Nguyễn Cường,Mua bán nhà, chung cư, bất động s...    NaN
# ...

# %%
df.dropna(subset=['a_text'], inplace=True)

# %%
df[df.duplicated(subset=['a_text'])]
# Out:
#                    a_date        a_post_id  \
# 24    2020-08-09 21:00:38  967306867119371
# 41    2020-08-09 21:05:41  967310117119046
# 59    2020-08-09 21:45:14  967335613783163
# 64    2020-08-09 21:38:46  967331890450202
# 65    2020-08-09 21:40:17  967332803783444
# ...                   ...              ...
# 9194  2020-08-01 20:49:15  961149611068430
# 9195  2020-08-01 20:48:52  961149274401797
# 9196  2020-08-01 20:48:39  961149141068477
# 9197  2020-08-01 20:48:33  961149064401818
# 9198  2020-08-01 20:47:26  961148384401886
#
#                                                a_source  \
# 24    Dang Phan,Mua bán nhà, chung cư, bất động sản ...
# 41    Vũ Tuấn Dương,Mua bán nhà, chung cư, bất động ...
# 59    Ngọc Sỹ,Mua bán nhà, chung cư, bất động sản Và...
# 64    Ngọc Sỹ,Mua bán nhà, chung cư, bất động sản Và...
# 65    Anh Trung,Mua bán nhà, chung cư, bất động sản ...
# ...                                                 ...
# ...

# %%
df.drop_duplicates(subset=['a_text'], inplace=True, ignore_index=True)

# %%
df[df.duplicated(subset=['a_text'])]
# Out:
# Empty DataFrame
# Columns: [index, a_date, a_post_id, a_source, a_text, b_url, d_comment_url, pictures]
# Index: []

# %%
df.sample(5)
# Out:
#       index               a_date        a_post_id  \
# 4078   7235  2020-08-10 15:31:09  967875623729162
# 4377   7668  2020-08-10 10:20:29  967723477077710
# 2554   3558  2020-08-12 16:56:41  969502586899799
# 2402   3031  2020-08-13 08:47:40  970047986845259
# 3978   7086  2020-08-10 17:27:16  967936903723034
#
#                                                a_source  \
# 4078  Đinh Tuấn,Mua bán nhà, chung cư, bất động sản ...
# 4377  Thùy Linh,Mua bán nhà, chung cư, bất động sản ...
# 2554  Lê Khánh,Mua bán nhà, chung cư, bất động sản V...
# 2402  Tiến Cenland,Mua bán nhà, chung cư, bất động s...
# 3978  Phan Cường,Mua bán nhà, chung cư, bất động sản...
#
#                                                  a_text  \
# 4078  :fire::fire::fire: Khi nhắc đến đầu tư THỜI ĐI...
# 4377  Tôi hiện đang có văn phòng ở Hoàng Quốc Việt m...
# 2554  Huyện Thanh Thuỷ, Phú Thọ 📞 : 0333.88.1912 / 0...
# 2402  🇻🇳🇻🇳 𝐔̛𝐔 Đ𝐀̃𝐈 𝐍𝐇𝐀̣̂𝐍 𝐍𝐇𝐀̀ #𝐒𝐔𝐍𝐒𝐇𝐈𝐍𝐄 𝐂𝐈𝐓𝐘 𝐓𝐇𝐀́𝐍...
# ...

# %%
df.reset_index(inplace=True)

# %%
df.shape
# Out:
# (5382, 8)

# %%
text = "0381.990.015"
text1 = "(+84)942205170"
print(re.match(r"((.+84.)|0)+([0-9\.]{9-11})\b", text).group())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-033a3a352b2e> in <module>
#       1 text = "0381.990.015"
#       2 text1 = "(+84)942205170"
# ----> 3 print(re.match(r"((.+84.)|0)+([0-9\.]{9-11})\b", text).group())
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
def filter(text):
    x = re.findall(r'(bán|nhà|biệt|thự|cư|ccmn|tỷ|m2)', str(text).lower())
    if x :
      return True
    return False

temp = df['a_text'].apply(filter)

# %%
df[temp==True]
# Out:
#       index               a_date        a_post_id  \
# 0         0  2020-07-14 11:05:14  947324092450982
# 1         1  2020-08-09 20:37:15  967291740454217
# 2         2  2020-08-09 21:15:23  967316327118425
# 3         3  2020-08-09 21:47:14  967336763783048
# 4         4  2020-08-09 21:18:02  967318063784918
# ...     ...                  ...              ...
# 5376   9117  2020-07-26 17:45:49  956566144860110
# 5377   9118  2020-07-26 17:45:23  956565818193476
# 5378   9119  2020-07-26 17:43:54  956564848193573
# 5379   9120  2020-07-26 17:43:13  956564301526961
# 5380   9121  2020-07-26 17:39:10  956561501527241
#
#                                                a_source  \
# 0     Hồ Hoàng Hiệp,Mua bán nhà, chung cư, bất động ...
# 1     Huy Duy,Mua bán nhà, chung cư, bất động sản Và...
# 2     Nguyễn Tú,Mua bán nhà, chung cư, bất động sản ...
# 3     Trần Phát,Mua bán nhà, chung cư, bất động sản ...
# 4     David Tuấn,Mua bán nhà, chung cư, bất động sản...
# ...

# %%
df[temp==False]
# Out:
#       index               a_date        a_post_id  \
# 24       25  2020-08-09 21:20:29  967319813784743
# 32       33  2020-08-09 20:48:50  967299303786794
# 58       61  2020-08-09 20:43:50  967296207120437
# 123     151  2020-08-09 20:22:54  967283150455076
# 167     207  2020-08-09 18:08:46  967187490464642
# ...     ...                  ...              ...
# 5331   9068  2020-07-26 19:00:10  956620151521376
# 5347   9084  2020-07-26 18:30:30  956604024856322
# 5350   9088  2020-07-26 18:27:15  956600941523297
# 5361   9100  2020-07-26 18:12:22  956586324858092
# 5381   9122  2020-07-26 17:37:21  956560291527362
#
#                                                a_source  \
# 24    Nguyễn Thanh,Mua bán nhà, chung cư, bất động s...
# 32    Quang Tèo,Mua bán nhà, chung cư, bất động sản ...
# 58    Quang Tèo,Mua bán nhà, chung cư, bất động sản ...
# 123   Dương Hien Anh,Mua bán nhà, chung cư, bất động...
# 167   Huyền El Dorado,Mua bán nhà, chung cư, bất độn...
# ...

# %%
text = df.at[5331, 'a_text']

# %%
text
# Out:
# '🍀🍀🍀Chính chu bán rất gấp Nhà liền kề văn quán, Hà Đông, hà nội 🌹🌹🌹Nhà 68m xây 4tầng , Mt 4.2m đg oto đỗ tránh vào nhà thoải mái, kinh doanh, tiện ích xung quanh ko thiếu gì, 🤣🤣🤣Nói đến hà đông, phải nhắc đến đất vàg văn quán, đầu tư, ở kd đều ok hết ạ, giá chỉ 6.7,ty thương lượng  🌹🌹🌹🌹Duyên chỉ đến 1lần, nhanh còn chậm bay call luôn và ngay 0968311389'

# %%
x = re.findall('(ty|nhà)', text.lower())

# %%
import regex
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-71-ff74d4b458aa> in <module>
# ----> 1 import regex
#
# ModuleNotFoundError: No module named 'regex'
